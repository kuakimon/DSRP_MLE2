# %% [markdown]
# # 02 - Machine Learning
#
# Entrena el modelo de clasificación fake/real, registra experimentos en MLflow y compara corridas.

# %%
import sys
sys.path.append('../src')

import mlflow
from fake_news_mle.train import train_model

# %% [markdown]
# ## Testing

# %%
with mlflow.start_run() as run:
    mlflow.log_param("test", "ok")
    mlflow.log_metric("accuracy", 0.95)

    print("Run ID:", run.info.run_id)
# Out:
# Run ID: 826b923bc6c34ad2856d9e8d5d15b5e8
# 🏃 View run bedecked-bat-27 at: http://127.0.0.1:5000/#/experiments/1/runs/826b923bc6c34ad2856d9e8d5d15b5e8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %% [markdown]
# ## Experimentos

# %%
metrics_v1 = train_model(max_features=10_000, ngram_max=1, C=1.0)
metrics_v1
# Out:
# 2026/09/02 15:22:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/09/02 15:23:57 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Métricas: {'accuracy': 0.989086859688196, 'precision': 0.9867441860465116, 'recall': 0.9904295051353875, 'f1_score': 0.9885834109972041, 'roc_auc': 0.998807366501399}
# 🏃 View run able-hare-513 at: http://127.0.0.1:5000/#/experiments/1/runs/e4a3a301deb442ce80f8bc600f5c9345
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# {'accuracy': 0.989086859688196,
#  'precision': 0.9867441860465116,
#  'recall': 0.9904295051353875,
#  'f1_score': 0.9885834109972041,
#  'roc_auc': 0.998807366501399}

# %%
metrics_v2 = train_model(max_features=20_000, ngram_max=2, C=1.0)
metrics_v2
# Out:
# 2026/09/02 15:25:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/09/02 15:25:57 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Métricas: {'accuracy': 0.9908685968819599, 'precision': 0.9879238272178356, 'recall': 0.9929971988795518, 'f1_score': 0.990454016298021, 'roc_auc': 0.9991277814362542}
# 🏃 View run amazing-cow-299 at: http://127.0.0.1:5000/#/experiments/1/runs/0a96435d4c604e969ec107dfba29f822
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# {'accuracy': 0.9908685968819599,
#  'precision': 0.9879238272178356,
#  'recall': 0.9929971988795518,
#  'f1_score': 0.990454016298021,
#  'roc_auc': 0.9991277814362542}

# %%
metrics_v3 = train_model(max_features=20_000, ngram_max=2, C=0.5)
metrics_v3
# Out:
# 2026/09/02 15:27:30 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/09/02 15:27:52 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Métricas: {'accuracy': 0.987305122494432, 'precision': 0.9828624363131079, 'recall': 0.9906629318394025, 'f1_score': 0.9867472680771914, 'roc_auc': 0.9986321473507063}
# 🏃 View run respected-flea-205 at: http://127.0.0.1:5000/#/experiments/1/runs/7b2c31af752a432d80f15568ebb79eba
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# {'accuracy': 0.987305122494432,
#  'precision': 0.9828624363131079,
#  'recall': 0.9906629318394025,
#  'f1_score': 0.9867472680771914,
#  'roc_auc': 0.9986321473507063}

# %% [markdown]
# ## MLflow
#
# ```bash
# uv run mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./mlartifacts --host 127.0.0.1 --port 5000
# ```
#
# http://localhost:5000
