# %% [markdown]
# # 01 - Preprocesamiento de datos
#
# Carga el dataset crudo (Fake.csv / True.csv), lo limpia y genera el dataset procesado usado por el notebook de Machine Learning.

# %%
import sys
sys.path.append('../src')

from fake_news_mle.preprocessing import load_raw_data, build_features, preprocess

# %% [markdown]
# ## Cargar datos crudos

# %%
df_raw = load_raw_data(raw_dir='../data/raw')
df_raw.head()
# Out:
#                                                title  \
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1  Trump drops Steve Bannon from National Securit...
# 2  Puerto Rico expects U.S. to lift Jones Act shi...
# 3   OOPS: Trump Just Accidentally Confirmed He Le...
# 4  Donald Trump heads for Scotland to reopen a go...
#
#                                                 text       subject  \
# 0  21st Century Wire says Ben Stein, reputable pr...       US_News
# 1  WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 2  (Reuters) - Puerto Rico Governor Ricardo Rosse...  politicsNews
# 3  On Monday, Donald Trump once again embarrassed...          News
# 4  GLASGOW, Scotland (Reuters) - Most U.S. presid...  politicsNews
#
#                   date  label
# 0    February 13, 2017      0
# 1       April 5, 2017       1
# 2  September 27, 2017       1
# 3         May 22, 2017      0
# 4       June 24, 2016       1

# %% [markdown]
# ## Conteos

# %%
print(df_raw['label'].value_counts())
print(df_raw['subject'].value_counts())
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64
# subject
# politicsNews       11272
# worldnews          10145
# News                9050
# politics            6841
# left-news           4459
# Government News     1570
# US_News              783
# Middle-east          778
# Name: count, dtype: int64

# %% [markdown]
# ## Construir features y limpiar texto

# %%
df_features = build_features(df_raw)
df_features.head()
# Out:
#                                                title       subject  \
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...       US_News
# 1  Trump drops Steve Bannon from National Securit...  politicsNews
# 2  Puerto Rico expects U.S. to lift Jones Act shi...  politicsNews
# 3   OOPS: Trump Just Accidentally Confirmed He Le...          News
# 4  Donald Trump heads for Scotland to reopen a go...  politicsNews
#
#                   date                                         clean_text  \
# 0    February 13, 2017  ben stein calls out th circuit court committed...
# 1       April 5, 2017   trump drops steve bannon from national securit...
# 2  September 27, 2017   puerto rico expects us to lift jones act shipp...
# 3         May 22, 2017  oops trump just accidentally confirmed he leak...
# 4       June 24, 2016   donald trump heads for scotland to reopen a go...
#
#    text_length  label
# 0          184      0
# 1          775      1
# 2          313      1
# 3          192      0
# 4          529      1

# %% [markdown]
# ## Guardar dataset procesado

# %%
df_final = preprocess(raw_dir='../data/raw', processed_dir='../data/processed')
df_final.shape
# Out:
# Dataset procesado guardado en: ..\data\processed\news_processed.parquet (44898 filas)
# (44898, 6)
